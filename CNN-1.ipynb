# %%
import pickle

with open('testX.pkl', 'rb') as f:
    testX = pickle.load(f)


with open('testY.pkl', 'rb') as f:
    testY = pickle.load(f)


with open('le.pkl', 'rb') as f:
    le = pickle.load(f)

# %%
from tensorflow import keras

import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# 2021-09-16 10:41:05.814072: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1

# %%
batch_size = 10

# %%
def metrics(model, batch_size=40):    
    predIdxs = model.predict(testX, batch_size=batch_size)
    predIdxs = np.argmax(predIdxs, axis=1)
    print(classification_report(testY.argmax(axis=1), predIdxs, target_names=le.classes_, digits = 5))
    modelLoss, modelAccuracy = model.evaluate(testX, testY)

    print('Test Loss is {}'.format(modelLoss))
    print('Test Accuracy is {}'.format(modelAccuracy ))
    class_names = ['Covid-19', 'Lung Opacity', 'Normal', 'Pneumonia']
    y_pred = model.predict(testX)
    print(class_names[np.argmax(y_pred[11])])
    x = confusion_matrix(testY.argmax(axis=1),y_pred.argmax(axis=1))
    Confusion_Matrix = pd.DataFrame(x,index=class_names, columns=class_names)

    sns.set(font_scale=1.5, color_codes=True, palette='deep')
    sns.heatmap(Confusion_Matrix, annot=True, annot_kws={'size':16}, fmt='d', cmap='YlGnBu')

    plt.ylabel("Actual")
    plt.xlabel("Predicted")
    plt.title('Confusion Matrix')
    plt.show()

# %%
model = keras.models.load_model('CNN_Covid19_Xray_V2.h5')
metrics(model)
# modelRESNET = keras.models.load_model('resnet50_model.h5')
# metrics(modelRESNET)
# modelVGG = keras.models.load_model('vgg16_model.h5')
# metrics(modelVGG)
# modelINC = keras.models.load_model('inc_history_model.h5')
# metrics(modelINC)
# Out:
# 2021-09-16 10:41:07.224766: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-09-16 10:41:07.225336: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-09-16 10:41:07.269479: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-16 10:41:07.269914: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce GTX 1060 6GB computeCapability: 6.1
# coreClock: 1.7715GHz coreCount: 10 deviceMemorySize: 5.93GiB deviceMemoryBandwidth: 178.99GiB/s
# 2021-09-16 10:41:07.269954: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2021-09-16 10:41:07.271940: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2021-09-16 10:41:07.272007: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2021-09-16 10:41:07.273832: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2021-09-16 10:41:07.274165: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2021-09-16 10:41:07.276158: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2021-09-16 10:41:07.277403: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2021-09-16 10:41:07.281827: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2021-09-16 10:41:07.281993: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-16 10:41:07.282501: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-16 10:41:07.282879: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2021-09-16 10:41:07.284373: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-09-16 10:41:07.285009: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-16 10:41:07.285417: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce GTX 1060 6GB computeCapability: 6.1
# coreClock: 1.7715GHz coreCount: 10 deviceMemorySize: 5.93GiB deviceMemoryBandwidth: 178.99GiB/s
# 2021-09-16 10:41:07.285458: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2021-09-16 10:41:07.285490: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2021-09-16 10:41:07.285519: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2021-09-16 10:41:07.285547: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2021-09-16 10:41:07.285575: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2021-09-16 10:41:07.285602: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2021-09-16 10:41:07.285630: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2021-09-16 10:41:07.285658: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2021-09-16 10:41:07.285756: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-16 10:41:07.286210: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-16 10:41:07.286581: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2021-09-16 10:41:07.286630: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2021-09-16 10:41:07.579099: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-09-16 10:41:07.579124: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0
# 2021-09-16 10:41:07.579129: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N
# 2021-09-16 10:41:07.579280: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-16 10:41:07.579514: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-16 10:41:07.579717: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-16 10:41:07.579897: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 5175 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce GTX 1060 6GB, pci bus id: 0000:01:00.0, compute capability: 6.1)
# 2021-09-16 10:41:07.580144: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-09-16 10:41:08.377918: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2021-09-16 10:41:08.397047: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 3000000000 Hz
# 2021-09-16 10:41:08.547180: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2021-09-16 10:41:08.635854: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
#               precision    recall  f1-score   support
#
#     Covid-19    0.94455   0.68326   0.79294       723
# Lung Opacity    0.86123   0.82612   0.84331      1202
#       Normal    0.84652   0.94949   0.89505      2039
#    Pneumonia    0.90741   0.91078   0.90909       269
#
#     accuracy                        0.86652      4233
#    macro avg    0.88993   0.84241   0.86010      4233
# weighted avg    0.87131   0.86652   0.86381      4233
#
# 133/133 [==============================] - 3s 21ms/step - loss: 0.3502 - accuracy: 0.8665
# Test Loss is 0.3502492308616638
# Test Accuracy is 0.8665249347686768
# Normal

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 150, 150, 8)       224
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 150, 150, 8)       584
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 149, 149, 8)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 149, 149, 16)      1168
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 149, 149, 16)      2320
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 74, 74, 16)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 74, 74, 32)        4640
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 74, 74, 32)        9248
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 37, 37, 32)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 37, 37, 64)        18496
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 37, 37, 64)        36928
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 18, 18, 64)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 18, 18, 512)       295424
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 9, 9, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 41472)             0
# _________________________________________________________________
# dense (Dense)                (None, 64)                2654272
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 260
# =================================================================
# Total params: 3,023,564
# Trainable params: 3,023,564
# Non-trainable params: 0
# _________________________________________________________________

# %%
predIdxs = model.predict(testX, batch_size=batch_size)

# %%
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import roc_auc_score
from sklearn.multiclass import OneVsRestClassifier
import sklearn
from sklearn.preprocessing import label_binarize

# %%
fpr, tpr, thresh = roc_curve(testY.argmax(axis=1),predIdxs.argmax(axis=1), pos_label=1)
random_probs = [0 for i in range(len(testY))]
p_fpr, p_tpr, _ = roc_curve(testY.argmax(axis=1), random_probs, pos_label=1)

# %%
class_names = ['Covid-19', 'Lung Opacity', 'Normal', 'Pneumonia']

auc_score = roc_auc_score(testY, predIdxs, multi_class='ovo')
auc_score
# Out:
# 0.8637426621903277

# %%
fpr = {}
tpr = {}
roc_auc ={}
y = label_binarize(testY, classes=[0, 1, 2,3])
n_classes = y.shape[1]

# %%
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(testY[:, i], predIdxs[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# %%
plt.figure(figsize=(20,10))
plt.plot(fpr[0], tpr[0], linestyle='--',color='orange', label=le.classes_[0] +' vs Rest')
plt.plot(fpr[1], tpr[1], linestyle='--',color='green', label=le.classes_[1]+ ' vs Rest')
plt.plot(fpr[2], tpr[2], linestyle='--',color='blue', label=le.classes_[2]+' vs Rest')
plt.plot(fpr[3], tpr[3], linestyle='--',color='red', label=le.classes_[3]+' vs Rest')

plt.title('Multiclass ROC curve CNN')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive rate')
plt.legend(loc='best')
plt.show()

# %%
for i in roc_auc.keys():
    print("auc for " + str(le.classes_[i])+ ' = ' + str(roc_auc[i]))
# Out:
# auc for Covid-19 = 0.8329542543927053
# auc for Lung Opacity = 0.7022670892183982
# auc for Normal = 0.9352737838225702
# auc for Pneumonia = 0.9844755213276366

# %%
le.classes_
# Out:
# array(['Covid-19', 'Lung Opacity', 'Normal', 'Pneumonia'], dtype='<U12')
